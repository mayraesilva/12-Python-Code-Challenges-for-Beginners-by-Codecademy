# %% [markdown]
# <a href="https://colab.research.google.com/github/mayraesilva/12-Python-Code-Challenges-for-Beginners-by-Codecademy/blob/main/Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
database = pd.read_csv('database_star_galaxy.csv')

# %%
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ra          1000 non-null   float64
#  1   dec         1000 non-null   float64
#  2   mag_auto_g  1000 non-null   float64
#  3   mag_auto_r  1000 non-null   float64
#  4   mag_auto_i  1000 non-null   float64
#  5   mag_auto_z  1000 non-null   float64
# dtypes: float64(6)
# memory usage: 47.0 KB

# %%
database.head()
# Out:
#            ra        dec  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 0   78.528192 -40.046594    7.870001    7.667336    7.815692    7.569540
# 1  300.436680 -59.375541   10.309841    8.586642    7.830778    9.282275
# 2  335.684282 -45.948059   10.846174    8.073956    8.166538   99.000000
# 3   29.695136 -61.569584   99.000000    9.670676    8.293428    7.696508
# 4   30.002144 -21.077951    8.248489    8.663001    8.315146    7.141654

# %%
plt.plot(database['ra'],database['mag_auto_g'],'*')
plt.ylim(5,25)
plt.xlabel('Ascenção da Reta')
plt.ylabel('Magnitude na banda G')
plt.show()
